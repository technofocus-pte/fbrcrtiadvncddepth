# %%
# Cell 0: Install required library for Azure Data Lake Storage upload
# !pip install azure-storage-blob

# Cell 1: Import libraries
import uuid
import random
import time
from datetime import datetime, timedelta
import threading
import xml.etree.ElementTree as ET
from azure.storage.blob import BlobServiceClient

# -- Configurable Variables --
BLOB_CONNECTION_STRING = "<YOUR_AZURE_BLOB_CONNECTION_STRING>"
CONTAINER_NAME = "shipping-events"

SHIPPING_PROVIDERS = ["FedEx", "DPD", "UPS"]

DISTRIBUTION_CENTERS = [
    {"country": "Germany", "city": "Berlin", "lat": 52.5200, "long": 13.4050}
 ]

DESTINATIONS = [
    {"country": "Germany", "city": "Berlin", "lat": 52.5200, "long": 13.4050},
    {"country": "China", "city": "Shanghai", "lat": 31.2304, "long": 121.4737},
    {"country": "USA", "city": "Austin", "lat": 30.2672, "long": -97.7431},
    {"country": "USA", "city": "Buffalo", "lat": 42.8864, "long": -78.8784},
    {"country": "Spain", "city": "Barcelona", "lat": 41.3851, "long": 2.1734},
    {"country": "India", "city": "Mumbai", "lat": 19.0760, "long": 72.8777},
    {"country": "France", "city": "Paris", "lat": 48.8566, "long": 2.3522},
    {"country": "UK", "city": "London", "lat": 51.5074, "long": -0.1278},
    {"country": "Italy", "city": "Rome", "lat": 41.9028, "long": 12.4964},
    {"country": "Netherlands", "city": "Amsterdam", "lat": 52.3676, "long": 4.9041}
 ]

# Initialize Azure Blob Service client
blob_service_client = BlobServiceClient.from_connection_string(BLOB_CONNECTION_STRING)
container_client = blob_service_client.get_container_client(CONTAINER_NAME)
try:
    container_client.create_container()
except Exception:
    pass  # Container may already exist

# --- Helper Functions ---
def random_address(destination):
    streets = ["Main St", "High St", "Elm St", "Oak St", "Maple Ave"]
    zip_code = str(random.randint(10000, 99999))
    street = random.choice(streets)
    number = str(random.randint(1, 200))
    return {
        "name": f"{random.choice(['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Andrew', 'John', 'Emma'])} {random.choice(['Smith', 'Johnson', 'Brown', 'Williams', 'Jones', 'Kieran'])}",
        "street": f"{street} {number}",
        "city": destination["city"],
        "zip": zip_code,
        "country": destination["country"],
        "latitude": destination["lat"],
        "longitude": destination["long"]
    }

def random_product():
    return {
        "ProductId": f"PROD{random.randint(4000, 4019)}",
        "size": random.choice(["36", "38", "40", "42", "44"]),
        "qty": random.randint(1, 3)
    }

def random_weight(item):
    return round(random.uniform(0.7, 1.2) * item["qty"], 2)

def random_provider():
    return random.choice(SHIPPING_PROVIDERS)

def random_distribution_center():
    return random.choice(DISTRIBUTION_CENTERS)

def random_destination():
    return random.choice(DESTINATIONS)

# --- Generate XML shipping event ---
def create_shipping_xml_event(order_number, src, dst, item, weight, provider, status, delay_reason, anomaly_flag, event_time):
    root = ET.Element("ShippingEvent")
    ET.SubElement(root, "Provider").text = provider
    ET.SubElement(root, "OrderNumber").text = order_number
    ET.SubElement(root, "EventTime").text = event_time
    ET.SubElement(root, "Status").text = status
    ET.SubElement(root, "DelayReason").text = delay_reason
    ET.SubElement(root, "AnomalyFlag").text = anomaly_flag

    dc = ET.SubElement(root, "SourceDistributionCenter")
    ET.SubElement(dc, "City").text = src["city"]
    ET.SubElement(dc, "Country").text = src["country"]
    ET.SubElement(dc, "Latitude").text = str(src["lat"])
    ET.SubElement(dc, "Longitude").text = str(src["long"])

    addr = ET.SubElement(root, "DestinationAddress")
    ET.SubElement(addr, "Name").text = dst["name"]
    ET.SubElement(addr, "Street").text = dst["street"]
    ET.SubElement(addr, "City").text = dst["city"]
    ET.SubElement(addr, "Zip").text = dst["zip"]
    ET.SubElement(addr, "Country").text = dst["country"]
    ET.SubElement(addr, "Latitude").text = str(dst["latitude"])
    ET.SubElement(addr, "Longitude").text = str(dst["longitude"])

    ship_info = ET.SubElement(root, "ShippingContents")
    prod = ET.SubElement(ship_info, "Product")
    ET.SubElement(prod, "ProductId").text = item["ProductId"]
    ET.SubElement(prod, "Size").text = item["size"]
    ET.SubElement(prod, "Quantity").text = str(item["qty"])

    ET.SubElement(root, "WeightKg").text = str(weight)

    return ET.tostring(root, encoding='utf-8', method='xml')

# --- Blob upload helper ---
def upload_xml_to_blob(xml_bytes, filename):
    blob_client = container_client.get_blob_client(filename)
    blob_client.upload_blob(xml_bytes, overwrite=True)

# --- Main Simulation ---
def simulate_shipping_events(rate_per_minute=6):
    interval = 60 / rate_per_minute
    order_event_status = {}  # Track status for each order_number

    try:
        while True:
            order_number = str(uuid.uuid4())
            src = random_distribution_center()
            dst_info = random_destination()
            dst = random_address(dst_info)
            provider = random_provider()
            item = random_product()
            weight = random_weight(item)

            delay_reason = random.choice(["Monsoon", "Port Closed", "None"])
            anomaly_flag = str(random.random() < 0.1).lower()

            # Store all order details for consistency
            order_event_status[order_number] = {
                "product_id": item["ProductId"],
                "provider": provider,
                "src": src,
                "dst": dst,
                "item": item,
                "weight": weight,
                "status": set()
            }

            # Dispatched
            status = "Dispatched"
            event_time = datetime.utcnow().isoformat() + "Z"
            xml_bytes = create_shipping_xml_event(order_number, src, dst, item, weight, provider, status, delay_reason, anomaly_flag, event_time)
            filename = f"{provider}_order_{order_number}_{item['ProductId']}_dispatched.xml"
            upload_xml_to_blob(xml_bytes, filename)
            print(f"Shipping event dispatched: {filename}")
            order_event_status[order_number]["status"].add("Dispatched")

            # PickedUp (some orders only)
            if random.random() < 0.7:
                status = "PickedUp"
                event_time = (datetime.utcnow() + timedelta(seconds=random.randint(10, 60))).isoformat() + "Z"
                xml_bytes_pickup = create_shipping_xml_event(order_number, src, dst, item, weight, provider, status, delay_reason, anomaly_flag, event_time)
                filename_pickup = f"{provider}_order_{order_number}_{item['ProductId']}_pickedup.xml"
                upload_xml_to_blob(xml_bytes_pickup, filename_pickup)
                print(f"Shipping event picked up: {filename_pickup}")
                order_event_status[order_number]["status"].add("PickedUp")

            # Routing (some orders only, only if PickedUp)
            if "PickedUp" in order_event_status[order_number]["status"] and random.random() < 0.5:
                status = "Routing"
                event_time = (datetime.utcnow() + timedelta(seconds=random.randint(61, 180))).isoformat() + "Z"
                xml_bytes_routing = create_shipping_xml_event(order_number, src, dst, item, weight, provider, status, delay_reason, anomaly_flag, event_time)
                filename_routing = f"{provider}_order_{order_number}_{item['ProductId']}_routing.xml"
                upload_xml_to_blob(xml_bytes_routing, filename_routing)
                print(f"Shipping event routing: {filename_routing}")
                order_event_status[order_number]["status"].add("Routing")

            time.sleep(interval)
    except KeyboardInterrupt:
        print("Simulation stopped.")

# --- Run Simulation in Background ---
thread = threading.Thread(target=simulate_shipping_events, args=(8,), daemon=True)
thread.start()

print("ZAVA shipping event simulator is running. Press Ctrl+C to stop the notebook.")

while True:
    time.sleep(5)
# Out:
# Requirement already satisfied: azure-storage-blob in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (12.26.0)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-storage-blob) (1.35.1)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-storage-blob) (46.0.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-storage-blob) (4.15.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.5)
# Requirement already satisfied: six>=1.11.0 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.17.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=2.1.4->azure-storage-blob) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sujosyul\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2025.8.3)
# ZAVA shipping event simulator is running. Press Ctrl+C to stop the notebook.
# ZAVA shipping event simulator is running. Press Ctrl+C to stop the notebook.
# Shipping event dispatched: FedEx_order_98f7b2f6-d091-41a5-bbf0-282461380a77_PROD4016_dispatched.xml
# Shipping event dispatched: FedEx_order_98f7b2f6-d091-41a5-bbf0-282461380a77_PROD4016_dispatched.xml
# Shipping event picked up: FedEx_order_98f7b2f6-d091-41a5-bbf0-282461380a77_PROD4016_pickedup.xml
# Shipping event picked up: FedEx_order_98f7b2f6-d091-41a5-bbf0-282461380a77_PROD4016_pickedup.xml
# Shipping event routing: FedEx_order_98f7b2f6-d091-41a5-bbf0-282461380a77_PROD4016_routing.xml
# Shipping event routing: FedEx_order_98f7b2f6-d091-41a5-bbf0-282461380a77_PROD4016_routing.xml
# Shipping event dispatched: DPD_order_82d3cd69-20d4-4c87-912a-dbc107e3bca5_PROD4004_dispatched.xml
# Shipping event dispatched: DPD_order_82d3cd69-20d4-4c87-912a-dbc107e3bca5_PROD4004_dispatched.xml
# Shipping event dispatched: UPS_order_f1070eaa-7bbc-49cb-ab91-153e6f7c544c_PROD4016_dispatched.xml
# Shipping event dispatched: UPS_order_f1070eaa-7bbc-49cb-ab91-153e6f7c544c_PROD4016_dispatched.xml
# Shipping event picked up: UPS_order_f1070eaa-7bbc-49cb-ab91-153e6f7c544c_PROD4016_pickedup.xml
# Shipping event picked up: UPS_order_f1070eaa-7bbc-49cb-ab91-153e6f7c544c_PROD4016_pickedup.xml
# Shipping event routing: UPS_order_f1070eaa-7bbc-49cb-ab91-153e6f7c544c_PROD4016_routing.xml
# Shipping event routing: UPS_order_f1070eaa-7bbc-49cb-ab91-153e6f7c544c_PROD4016_routing.xml
# Shipping event dispatched: UPS_order_7739bc0e-f7f3-4a0f-b983-2ed8bba4cfba_PROD4009_dispatched.xml
# Shipping event dispatched: UPS_order_7739bc0e-f7f3-4a0f-b983-2ed8bba4cfba_PROD4009_dispatched.xml
# Shipping event picked up: UPS_order_7739bc0e-f7f3-4a0f-b983-2ed8bba4cfba_PROD4009_pickedup.xml
# Shipping event picked up: UPS_order_7739bc0e-f7f3-4a0f-b983-2ed8bba4cfba_PROD4009_pickedup.xml
# Shipping event routing: UPS_order_7739bc0e-f7f3-4a0f-b983-2ed8bba4cfba_PROD4009_routing.xml
# Shipping event routing: UPS_order_7739bc0e-f7f3-4a0f-b983-2ed8bba4cfba_PROD4009_routing.xml
# Shipping event dispatched: DPD_order_8adeae41-8816-47ff-8fd4-9215a7329af3_PROD4012_dispatched.xml
# Shipping event dispatched: DPD_order_8adeae41-8816-47ff-8fd4-9215a7329af3_PROD4012_dispatched.xml
# Shipping event dispatched: UPS_order_6468f9a2-e6aa-44de-b05c-4389cef62248_PROD4006_dispatched.xml
# Shipping event dispatched: UPS_order_6468f9a2-e6aa-44de-b05c-4389cef62248_PROD4006_dispatched.xml
# Shipping event picked up: UPS_order_6468f9a2-e6aa-44de-b05c-4389cef62248_PROD4006_pickedup.xml
# Shipping event picked up: UPS_order_6468f9a2-e6aa-44de-b05c-4389cef62248_PROD4006_pickedup.xml
# Shipping event dispatched: UPS_order_c5d2f24c-10e6-4626-a7a9-292bdc51339c_PROD4017_dispatched.xml
# Shipping event dispatched: UPS_order_c5d2f24c-10e6-4626-a7a9-292bdc51339c_PROD4017_dispatched.xml
# Shipping event picked up: UPS_order_c5d2f24c-10e6-4626-a7a9-292bdc51339c_PROD4017_pickedup.xml
# Shipping event picked up: UPS_order_c5d2f24c-10e6-4626-a7a9-292bdc51339c_PROD4017_pickedup.xml
# Shipping event dispatched: DPD_order_fff9457e-acd1-4a38-8342-4baea6495039_PROD4008_dispatched.xml
# Shipping event dispatched: DPD_order_fff9457e-acd1-4a38-8342-4baea6495039_PROD4008_dispatched.xml
# Shipping event picked up: DPD_order_fff9457e-acd1-4a38-8342-4baea6495039_PROD4008_pickedup.xml
# Shipping event picked up: DPD_order_fff9457e-acd1-4a38-8342-4baea6495039_PROD4008_pickedup.xml
# Shipping event routing: DPD_order_fff9457e-acd1-4a38-8342-4baea6495039_PROD4008_routing.xml
# Shipping event routing: DPD_order_fff9457e-acd1-4a38-8342-4baea6495039_PROD4008_routing.xml
# Shipping event dispatched: DPD_order_e6044a6f-fe99-480d-ad69-c24c0ab222fc_PROD4010_dispatched.xml
# Shipping event dispatched: DPD_order_e6044a6f-fe99-480d-ad69-c24c0ab222fc_PROD4010_dispatched.xml
# Shipping event picked up: DPD_order_e6044a6f-fe99-480d-ad69-c24c0ab222fc_PROD4010_pickedup.xml
# Shipping event picked up: DPD_order_e6044a6f-fe99-480d-ad69-c24c0ab222fc_PROD4010_pickedup.xml
# Shipping event routing: DPD_order_e6044a6f-fe99-480d-ad69-c24c0ab222fc_PROD4010_routing.xml
# Shipping event routing: DPD_order_e6044a6f-fe99-480d-ad69-c24c0ab222fc_PROD4010_routing.xml
# Shipping event dispatched: DPD_order_75756a89-add3-44b1-9fc1-8768ffb4837d_PROD4012_dispatched.xml
# Shipping event dispatched: DPD_order_75756a89-add3-44b1-9fc1-8768ffb4837d_PROD4012_dispatched.xml
# Shipping event dispatched: UPS_order_22cc5434-463b-4fb5-a613-a3a1096c446a_PROD4016_dispatched.xml
# Shipping event dispatched: UPS_order_22cc5434-463b-4fb5-a613-a3a1096c446a_PROD4016_dispatched.xml
# Shipping event dispatched: DPD_order_0b3b014b-e175-450c-a962-fcac5a8bae8b_PROD4015_dispatched.xml
# Shipping event dispatched: DPD_order_0b3b014b-e175-450c-a962-fcac5a8bae8b_PROD4015_dispatched.xml
# Shipping event picked up: DPD_order_0b3b014b-e175-450c-a962-fcac5a8bae8b_PROD4015_pickedup.xml
# Shipping event picked up: DPD_order_0b3b014b-e175-450c-a962-fcac5a8bae8b_PROD4015_pickedup.xml
# Shipping event dispatched: FedEx_order_e3398355-a300-4fbf-b1a9-71fdb37d23f7_PROD4002_dispatched.xml
# Shipping event dispatched: FedEx_order_e3398355-a300-4fbf-b1a9-71fdb37d23f7_PROD4002_dispatched.xml
# Shipping event dispatched: DPD_order_0cb3aae4-ee04-4083-8961-19071a424b74_PROD4019_dispatched.xml
# Shipping event dispatched: DPD_order_0cb3aae4-ee04-4083-8961-19071a424b74_PROD4019_dispatched.xml
# Shipping event picked up: DPD_order_0cb3aae4-ee04-4083-8961-19071a424b74_PROD4019_pickedup.xml
# Shipping event picked up: DPD_order_0cb3aae4-ee04-4083-8961-19071a424b74_PROD4019_pickedup.xml
# Shipping event dispatched: FedEx_order_b8e5c01a-ab3e-4132-abf7-57fa308521c2_PROD4011_dispatched.xml
# Shipping event dispatched: FedEx_order_b8e5c01a-ab3e-4132-abf7-57fa308521c2_PROD4011_dispatched.xml
# Shipping event picked up: FedEx_order_b8e5c01a-ab3e-4132-abf7-57fa308521c2_PROD4011_pickedup.xml
# Shipping event picked up: FedEx_order_b8e5c01a-ab3e-4132-abf7-57fa308521c2_PROD4011_pickedup.xml
# Shipping event dispatched: FedEx_order_2a4493ec-edd7-41f7-a39c-2886b932bda2_PROD4005_dispatched.xml
# Shipping event dispatched: FedEx_order_2a4493ec-edd7-41f7-a39c-2886b932bda2_PROD4005_dispatched.xml
# Shipping event picked up: FedEx_order_2a4493ec-edd7-41f7-a39c-2886b932bda2_PROD4005_pickedup.xml
# Shipping event picked up: FedEx_order_2a4493ec-edd7-41f7-a39c-2886b932bda2_PROD4005_pickedup.xml
# Shipping event routing: FedEx_order_2a4493ec-edd7-41f7-a39c-2886b932bda2_PROD4005_routing.xml
# Shipping event routing: FedEx_order_2a4493ec-edd7-41f7-a39c-2886b932bda2_PROD4005_routing.xml
# Shipping event dispatched: DPD_order_f9a38e08-1e4f-4ca8-8217-b68d2d43b9c6_PROD4007_dispatched.xml
# Shipping event dispatched: DPD_order_f9a38e08-1e4f-4ca8-8217-b68d2d43b9c6_PROD4007_dispatched.xml
# Shipping event picked up: DPD_order_f9a38e08-1e4f-4ca8-8217-b68d2d43b9c6_PROD4007_pickedup.xml
# Shipping event picked up: DPD_order_f9a38e08-1e4f-4ca8-8217-b68d2d43b9c6_PROD4007_pickedup.xml
# Shipping event routing: DPD_order_f9a38e08-1e4f-4ca8-8217-b68d2d43b9c6_PROD4007_routing.xml
# Shipping event routing: DPD_order_f9a38e08-1e4f-4ca8-8217-b68d2d43b9c6_PROD4007_routing.xml
# Shipping event dispatched: DPD_order_0870711d-8891-4406-b4fe-a6664e274f02_PROD4014_dispatched.xml
# Shipping event dispatched: DPD_order_0870711d-8891-4406-b4fe-a6664e274f02_PROD4014_dispatched.xml
# Shipping event picked up: DPD_order_0870711d-8891-4406-b4fe-a6664e274f02_PROD4014_pickedup.xml
# Shipping event picked up: DPD_order_0870711d-8891-4406-b4fe-a6664e274f02_PROD4014_pickedup.xml
# Shipping event dispatched: UPS_order_983c232e-ab5e-47ae-992e-e3863f871e54_PROD4008_dispatched.xml
# Shipping event dispatched: UPS_order_983c232e-ab5e-47ae-992e-e3863f871e54_PROD4008_dispatched.xml
# Shipping event picked up: UPS_order_983c232e-ab5e-47ae-992e-e3863f871e54_PROD4008_pickedup.xml
# Shipping event picked up: UPS_order_983c232e-ab5e-47ae-992e-e3863f871e54_PROD4008_pickedup.xml
# Shipping event routing: UPS_order_983c232e-ab5e-47ae-992e-e3863f871e54_PROD4008_routing.xml
# Shipping event routing: UPS_order_983c232e-ab5e-47ae-992e-e3863f871e54_PROD4008_routing.xml
# Shipping event dispatched: FedEx_order_94e05393-f855-46d8-a2f3-fe84c6f9321b_PROD4003_dispatched.xml
# Shipping event dispatched: FedEx_order_94e05393-f855-46d8-a2f3-fe84c6f9321b_PROD4003_dispatched.xml
# Shipping event picked up: FedEx_order_94e05393-f855-46d8-a2f3-fe84c6f9321b_PROD4003_pickedup.xml
# Shipping event picked up: FedEx_order_94e05393-f855-46d8-a2f3-fe84c6f9321b_PROD4003_pickedup.xml
# Shipping event routing: FedEx_order_94e05393-f855-46d8-a2f3-fe84c6f9321b_PROD4003_routing.xml
# Shipping event routing: FedEx_order_94e05393-f855-46d8-a2f3-fe84c6f9321b_PROD4003_routing.xml
# Shipping event dispatched: FedEx_order_50a74cdc-3b4c-4063-921e-54dcf0ea4ae9_PROD4014_dispatched.xml
# Shipping event dispatched: FedEx_order_50a74cdc-3b4c-4063-921e-54dcf0ea4ae9_PROD4014_dispatched.xml
# Shipping event dispatched: FedEx_order_7884adeb-25dc-40d1-b2d2-795e57129b21_PROD4006_dispatched.xml
# Shipping event dispatched: FedEx_order_7884adeb-25dc-40d1-b2d2-795e57129b21_PROD4006_dispatched.xml
# Shipping event picked up: FedEx_order_7884adeb-25dc-40d1-b2d2-795e57129b21_PROD4006_pickedup.xml
# Shipping event picked up: FedEx_order_7884adeb-25dc-40d1-b2d2-795e57129b21_PROD4006_pickedup.xml
# Shipping event routing: FedEx_order_7884adeb-25dc-40d1-b2d2-795e57129b21_PROD4006_routing.xml
# Shipping event routing: FedEx_order_7884adeb-25dc-40d1-b2d2-795e57129b21_PROD4006_routing.xml
# Shipping event dispatched: UPS_order_35a57156-061a-4267-926e-970be753825c_PROD4014_dispatched.xml
# Shipping event dispatched: UPS_order_35a57156-061a-4267-926e-970be753825c_PROD4014_dispatched.xml
# Shipping event dispatched: FedEx_order_d9ffc74c-301c-4b24-906e-1de301a0cab4_PROD4011_dispatched.xml
# Shipping event dispatched: FedEx_order_d9ffc74c-301c-4b24-906e-1de301a0cab4_PROD4011_dispatched.xml
# Shipping event picked up: FedEx_order_d9ffc74c-301c-4b24-906e-1de301a0cab4_PROD4011_pickedup.xml
# Shipping event picked up: FedEx_order_d9ffc74c-301c-4b24-906e-1de301a0cab4_PROD4011_pickedup.xml
# Shipping event routing: FedEx_order_d9ffc74c-301c-4b24-906e-1de301a0cab4_PROD4011_routing.xml
# Shipping event routing: FedEx_order_d9ffc74c-301c-4b24-906e-1de301a0cab4_PROD4011_routing.xml
# Shipping event dispatched: UPS_order_c9abc6fc-d760-47a7-b738-c4d0d5aeb583_PROD4008_dispatched.xml
# Shipping event dispatched: UPS_order_c9abc6fc-d760-47a7-b738-c4d0d5aeb583_PROD4008_dispatched.xml
# Shipping event dispatched: DPD_order_c28c8363-2754-41f6-99fa-fd70931195a6_PROD4005_dispatched.xml
# Shipping event dispatched: DPD_order_c28c8363-2754-41f6-99fa-fd70931195a6_PROD4005_dispatched.xml
# Shipping event dispatched: FedEx_order_c08a2ab1-65e2-4d88-9c19-339354a6e273_PROD4005_dispatched.xml
# Shipping event dispatched: FedEx_order_c08a2ab1-65e2-4d88-9c19-339354a6e273_PROD4005_dispatched.xml
# Shipping event picked up: FedEx_order_c08a2ab1-65e2-4d88-9c19-339354a6e273_PROD4005_pickedup.xml
# Shipping event picked up: FedEx_order_c08a2ab1-65e2-4d88-9c19-339354a6e273_PROD4005_pickedup.xml
# Shipping event routing: FedEx_order_c08a2ab1-65e2-4d88-9c19-339354a6e273_PROD4005_routing.xml
# Shipping event routing: FedEx_order_c08a2ab1-65e2-4d88-9c19-339354a6e273_PROD4005_routing.xml
# Shipping event dispatched: DPD_order_e6be2823-b1f6-4c32-94de-d01cfd76fcff_PROD4005_dispatched.xml
# Shipping event dispatched: DPD_order_e6be2823-b1f6-4c32-94de-d01cfd76fcff_PROD4005_dispatched.xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 188
#     185 print("ZAVA shipping event simulator is running. Press Ctrl+C to stop the notebook.")
#     187 while True:
# --> 188     time.sleep(5)
#
# KeyboardInterrupt:
# Shipping event dispatched: FedEx_order_c169aac7-4256-476b-a80c-4889ce1b74cc_PROD4004_dispatched.xml
# Shipping event dispatched: DPD_order_d32021b8-89cb-4813-af28-8ec22d1f5c92_PROD4017_dispatched.xml
# Shipping event picked up: DPD_order_d32021b8-89cb-4813-af28-8ec22d1f5c92_PROD4017_pickedup.xml
# Shipping event picked up: DPD_order_d32021b8-89cb-4813-af28-8ec22d1f5c92_PROD4017_pickedup.xml
# Shipping event dispatched: UPS_order_19ec0251-133d-4775-81e0-c4c76fae24ce_PROD4014_dispatched.xml
# Shipping event dispatched: UPS_order_19ec0251-133d-4775-81e0-c4c76fae24ce_PROD4014_dispatched.xml
# Shipping event picked up: UPS_order_19ec0251-133d-4775-81e0-c4c76fae24ce_PROD4014_pickedup.xml
# Shipping event picked up: UPS_order_19ec0251-133d-4775-81e0-c4c76fae24ce_PROD4014_pickedup.xml
# Shipping event routing: UPS_order_19ec0251-133d-4775-81e0-c4c76fae24ce_PROD4014_routing.xml
# Shipping event routing: UPS_order_19ec0251-133d-4775-81e0-c4c76fae24ce_PROD4014_routing.xml
# Shipping event dispatched: FedEx_order_1e0058be-484f-4f98-86d1-7cd5f9fba085_PROD4015_dispatched.xml
# Shipping event dispatched: FedEx_order_1e0058be-484f-4f98-86d1-7cd5f9fba085_PROD4015_dispatched.xml
# Shipping event dispatched: FedEx_order_1fd9d215-874e-49f6-83af-69312cc3ca1a_PROD4018_dispatched.xml
# Shipping event dispatched: FedEx_order_1fd9d215-874e-49f6-83af-69312cc3ca1a_PROD4018_dispatched.xml
# Shipping event picked up: FedEx_order_1fd9d215-874e-49f6-83af-69312cc3ca1a_PROD4018_pickedup.xml
# Shipping event picked up: FedEx_order_1fd9d215-874e-49f6-83af-69312cc3ca1a_PROD4018_pickedup.xml
# Shipping event routing: FedEx_order_1fd9d215-874e-49f6-83af-69312cc3ca1a_PROD4018_routing.xml
# Shipping event routing: FedEx_order_1fd9d215-874e-49f6-83af-69312cc3ca1a_PROD4018_routing.xml
# Shipping event dispatched: UPS_order_4ff377f6-8aa1-4294-a8e2-ea479711d2d6_PROD4007_dispatched.xml
# Shipping event dispatched: UPS_order_4ff377f6-8aa1-4294-a8e2-ea479711d2d6_PROD4007_dispatched.xml
# Shipping event picked up: UPS_order_4ff377f6-8aa1-4294-a8e2-ea479711d2d6_PROD4007_pickedup.xml
# Shipping event picked up: UPS_order_4ff377f6-8aa1-4294-a8e2-ea479711d2d6_PROD4007_pickedup.xml
# Shipping event routing: UPS_order_4ff377f6-8aa1-4294-a8e2-ea479711d2d6_PROD4007_routing.xml
# Shipping event routing: UPS_order_4ff377f6-8aa1-4294-a8e2-ea479711d2d6_PROD4007_routing.xml
# Shipping event dispatched: FedEx_order_27cbe27d-0774-41ef-a389-1ab9dd61fe39_PROD4014_dispatched.xml
# Shipping event dispatched: FedEx_order_27cbe27d-0774-41ef-a389-1ab9dd61fe39_PROD4014_dispatched.xml
# Shipping event dispatched: FedEx_order_1c97b779-9860-483a-acea-97359aad8766_PROD4018_dispatched.xml
# Shipping event dispatched: FedEx_order_1c97b779-9860-483a-acea-97359aad8766_PROD4018_dispatched.xml
# Shipping event picked up: FedEx_order_1c97b779-9860-483a-acea-97359aad8766_PROD4018_pickedup.xml
# Shipping event picked up: FedEx_order_1c97b779-9860-483a-acea-97359aad8766_PROD4018_pickedup.xml
# Shipping event routing: FedEx_order_1c97b779-9860-483a-acea-97359aad8766_PROD4018_routing.xml
# Shipping event routing: FedEx_order_1c97b779-9860-483a-acea-97359aad8766_PROD4018_routing.xml
# Shipping event dispatched: UPS_order_9606cee3-88b7-416c-9bad-7149e24ea4d9_PROD4014_dispatched.xml
# Shipping event dispatched: UPS_order_9606cee3-88b7-416c-9bad-7149e24ea4d9_PROD4014_dispatched.xml
# Shipping event dispatched: FedEx_order_9c4d699d-3c60-406c-8954-93e6159858ca_PROD4015_dispatched.xml
# Shipping event dispatched: FedEx_order_9c4d699d-3c60-406c-8954-93e6159858ca_PROD4015_dispatched.xml
# Shipping event picked up: FedEx_order_9c4d699d-3c60-406c-8954-93e6159858ca_PROD4015_pickedup.xml
# Shipping event picked up: FedEx_order_9c4d699d-3c60-406c-8954-93e6159858ca_PROD4015_pickedup.xml
# Shipping event routing: FedEx_order_9c4d699d-3c60-406c-8954-93e6159858ca_PROD4015_routing.xml
# Shipping event routing: FedEx_order_9c4d699d-3c60-406c-8954-93e6159858ca_PROD4015_routing.xml
# Shipping event dispatched: FedEx_order_fc41e248-036d-4a90-96e7-c97d1d104a7d_PROD4006_dispatched.xml
# Shipping event dispatched: FedEx_order_fc41e248-036d-4a90-96e7-c97d1d104a7d_PROD4006_dispatched.xml
# Shipping event dispatched: DPD_order_4d5cae66-4963-4de4-b62c-1e6c90f534c4_PROD4009_dispatched.xml
# Shipping event dispatched: DPD_order_4d5cae66-4963-4de4-b62c-1e6c90f534c4_PROD4009_dispatched.xml
# Shipping event picked up: DPD_order_4d5cae66-4963-4de4-b62c-1e6c90f534c4_PROD4009_pickedup.xml
# Shipping event picked up: DPD_order_4d5cae66-4963-4de4-b62c-1e6c90f534c4_PROD4009_pickedup.xml
# Shipping event dispatched: FedEx_order_d81ad381-c663-405f-9d32-662649683955_PROD4001_dispatched.xml
# Shipping event dispatched: FedEx_order_d81ad381-c663-405f-9d32-662649683955_PROD4001_dispatched.xml
# Shipping event picked up: FedEx_order_d81ad381-c663-405f-9d32-662649683955_PROD4001_pickedup.xml
# Shipping event picked up: FedEx_order_d81ad381-c663-405f-9d32-662649683955_PROD4001_pickedup.xml
# Shipping event routing: FedEx_order_d81ad381-c663-405f-9d32-662649683955_PROD4001_routing.xml
# Shipping event routing: FedEx_order_d81ad381-c663-405f-9d32-662649683955_PROD4001_routing.xml
# Shipping event dispatched: FedEx_order_c75c8de3-95bf-4739-a21d-2bfbdba46b7e_PROD4002_dispatched.xml
# Shipping event dispatched: FedEx_order_c75c8de3-95bf-4739-a21d-2bfbdba46b7e_PROD4002_dispatched.xml
# Shipping event picked up: FedEx_order_c75c8de3-95bf-4739-a21d-2bfbdba46b7e_PROD4002_pickedup.xml
# Shipping event picked up: FedEx_order_c75c8de3-95bf-4739-a21d-2bfbdba46b7e_PROD4002_pickedup.xml
# Shipping event dispatched: FedEx_order_6f330202-436c-43b0-8cf3-41034d77481d_PROD4019_dispatched.xml
# Shipping event dispatched: FedEx_order_6f330202-436c-43b0-8cf3-41034d77481d_PROD4019_dispatched.xml
# Shipping event picked up: FedEx_order_6f330202-436c-43b0-8cf3-41034d77481d_PROD4019_pickedup.xml
# Shipping event picked up: FedEx_order_6f330202-436c-43b0-8cf3-41034d77481d_PROD4019_pickedup.xml
# Shipping event dispatched: FedEx_order_24c38460-29df-49ee-9863-844699108584_PROD4004_dispatched.xml
# Shipping event dispatched: FedEx_order_24c38460-29df-49ee-9863-844699108584_PROD4004_dispatched.xml
# Shipping event picked up: FedEx_order_24c38460-29df-49ee-9863-844699108584_PROD4004_pickedup.xml
# Shipping event picked up: FedEx_order_24c38460-29df-49ee-9863-844699108584_PROD4004_pickedup.xml
# Shipping event dispatched: UPS_order_0d0cf974-3eb1-4837-9dfe-390578119e1c_PROD4015_dispatched.xml
# Shipping event dispatched: UPS_order_0d0cf974-3eb1-4837-9dfe-390578119e1c_PROD4015_dispatched.xml
# Shipping event picked up: UPS_order_0d0cf974-3eb1-4837-9dfe-390578119e1c_PROD4015_pickedup.xml
# Shipping event picked up: UPS_order_0d0cf974-3eb1-4837-9dfe-390578119e1c_PROD4015_pickedup.xml
# Shipping event dispatched: UPS_order_e9bf84af-070a-45e0-bf8d-99fc8c4bcfab_PROD4003_dispatched.xml
# Shipping event dispatched: UPS_order_e9bf84af-070a-45e0-bf8d-99fc8c4bcfab_PROD4003_dispatched.xml
# Shipping event picked up: UPS_order_e9bf84af-070a-45e0-bf8d-99fc8c4bcfab_PROD4003_pickedup.xml
# Shipping event picked up: UPS_order_e9bf84af-070a-45e0-bf8d-99fc8c4bcfab_PROD4003_pickedup.xml
# Shipping event dispatched: UPS_order_f63a2653-01ef-452b-99a6-3f0ad771618e_PROD4019_dispatched.xml
# Shipping event dispatched: UPS_order_f63a2653-01ef-452b-99a6-3f0ad771618e_PROD4019_dispatched.xml
# Shipping event dispatched: FedEx_order_8be945a2-9270-41fa-b31c-6b87acf3b28d_PROD4018_dispatched.xml
# Shipping event dispatched: FedEx_order_8be945a2-9270-41fa-b31c-6b87acf3b28d_PROD4018_dispatched.xml
# Shipping event picked up: FedEx_order_8be945a2-9270-41fa-b31c-6b87acf3b28d_PROD4018_pickedup.xml
# Shipping event picked up: FedEx_order_8be945a2-9270-41fa-b31c-6b87acf3b28d_PROD4018_pickedup.xml
# Shipping event routing: FedEx_order_8be945a2-9270-41fa-b31c-6b87acf3b28d_PROD4018_routing.xml
# Shipping event routing: FedEx_order_8be945a2-9270-41fa-b31c-6b87acf3b28d_PROD4018_routing.xml
# Shipping event dispatched: UPS_order_4fb45646-0329-4975-8341-8235ff569809_PROD4019_dispatched.xml
# Shipping event dispatched: UPS_order_4fb45646-0329-4975-8341-8235ff569809_PROD4019_dispatched.xml
# Shipping event dispatched: UPS_order_71a5e414-c50b-4b1f-b89c-caf7070e66d5_PROD4001_dispatched.xml
# Shipping event dispatched: UPS_order_71a5e414-c50b-4b1f-b89c-caf7070e66d5_PROD4001_dispatched.xml
# Shipping event picked up: UPS_order_71a5e414-c50b-4b1f-b89c-caf7070e66d5_PROD4001_pickedup.xml
# Shipping event picked up: UPS_order_71a5e414-c50b-4b1f-b89c-caf7070e66d5_PROD4001_pickedup.xml
# Shipping event routing: UPS_order_71a5e414-c50b-4b1f-b89c-caf7070e66d5_PROD4001_routing.xml
# Shipping event routing: UPS_order_71a5e414-c50b-4b1f-b89c-caf7070e66d5_PROD4001_routing.xml
# Shipping event dispatched: FedEx_order_67578209-36dc-4236-a11c-d3c02ddfe387_PROD4014_dispatched.xml
# Shipping event dispatched: FedEx_order_67578209-36dc-4236-a11c-d3c02ddfe387_PROD4014_dispatched.xml
# Shipping event picked up: FedEx_order_67578209-36dc-4236-a11c-d3c02ddfe387_PROD4014_pickedup.xml
# Shipping event picked up: FedEx_order_67578209-36dc-4236-a11c-d3c02ddfe387_PROD4014_pickedup.xml
# Shipping event routing: FedEx_order_67578209-36dc-4236-a11c-d3c02ddfe387_PROD4014_routing.xml
# Shipping event routing: FedEx_order_67578209-36dc-4236-a11c-d3c02ddfe387_PROD4014_routing.xml
# Shipping event dispatched: DPD_order_fecc2086-55eb-4efd-870a-ab424c7c64a2_PROD4000_dispatched.xml
# Shipping event dispatched: DPD_order_fecc2086-55eb-4efd-870a-ab424c7c64a2_PROD4000_dispatched.xml
# Shipping event picked up: DPD_order_fecc2086-55eb-4efd-870a-ab424c7c64a2_PROD4000_pickedup.xml
# Shipping event picked up: DPD_order_fecc2086-55eb-4efd-870a-ab424c7c64a2_PROD4000_pickedup.xml
# Shipping event routing: DPD_order_fecc2086-55eb-4efd-870a-ab424c7c64a2_PROD4000_routing.xml
# Shipping event routing: DPD_order_fecc2086-55eb-4efd-870a-ab424c7c64a2_PROD4000_routing.xml
# Shipping event dispatched: DPD_order_9de924f3-ae6f-4ea9-9d57-9a48558c0445_PROD4006_dispatched.xml
# Shipping event dispatched: DPD_order_9de924f3-ae6f-4ea9-9d57-9a48558c0445_PROD4006_dispatched.xml
# Shipping event picked up: DPD_order_9de924f3-ae6f-4ea9-9d57-9a48558c0445_PROD4006_pickedup.xml
# Shipping event picked up: DPD_order_9de924f3-ae6f-4ea9-9d57-9a48558c0445_PROD4006_pickedup.xml
# Shipping event routing: DPD_order_9de924f3-ae6f-4ea9-9d57-9a48558c0445_PROD4006_routing.xml
# Shipping event routing: DPD_order_9de924f3-ae6f-4ea9-9d57-9a48558c0445_PROD4006_routing.xml
# Shipping event dispatched: DPD_order_4f0ff9fc-2f89-4acb-bb18-e400555bd5fe_PROD4012_dispatched.xml
# Shipping event dispatched: DPD_order_4f0ff9fc-2f89-4acb-bb18-e400555bd5fe_PROD4012_dispatched.xml
# Shipping event picked up: DPD_order_4f0ff9fc-2f89-4acb-bb18-e400555bd5fe_PROD4012_pickedup.xml
# Shipping event picked up: DPD_order_4f0ff9fc-2f89-4acb-bb18-e400555bd5fe_PROD4012_pickedup.xml
# Shipping event routing: DPD_order_4f0ff9fc-2f89-4acb-bb18-e400555bd5fe_PROD4012_routing.xml
# Shipping event routing: DPD_order_4f0ff9fc-2f89-4acb-bb18-e400555bd5fe_PROD4012_routing.xml
# Shipping event dispatched: DPD_order_0b537bef-26b3-4e52-9729-16b0de732eb8_PROD4003_dispatched.xml
# Shipping event dispatched: DPD_order_0b537bef-26b3-4e52-9729-16b0de732eb8_PROD4003_dispatched.xml
# Shipping event dispatched: DPD_order_4bcb3db8-3bd8-43a7-9195-897a5ceb916e_PROD4003_dispatched.xml
# Shipping event dispatched: DPD_order_4bcb3db8-3bd8-43a7-9195-897a5ceb916e_PROD4003_dispatched.xml
# Shipping event dispatched: FedEx_order_5481d251-968a-426d-b18d-8755bfb2f055_PROD4001_dispatched.xml
# Shipping event dispatched: FedEx_order_5481d251-968a-426d-b18d-8755bfb2f055_PROD4001_dispatched.xml
# Shipping event picked up: FedEx_order_5481d251-968a-426d-b18d-8755bfb2f055_PROD4001_pickedup.xml
# Shipping event picked up: FedEx_order_5481d251-968a-426d-b18d-8755bfb2f055_PROD4001_pickedup.xml
# Shipping event routing: FedEx_order_5481d251-968a-426d-b18d-8755bfb2f055_PROD4001_routing.xml
# Shipping event routing: FedEx_order_5481d251-968a-426d-b18d-8755bfb2f055_PROD4001_routing.xml
# Shipping event dispatched: FedEx_order_078e8198-0a38-44e0-a01d-76b7321222f2_PROD4017_dispatched.xml
# Shipping event dispatched: FedEx_order_078e8198-0a38-44e0-a01d-76b7321222f2_PROD4017_dispatched.xml
# Shipping event dispatched: DPD_order_080294f0-d3ac-4dec-a8f1-0ba656c564de_PROD4015_dispatched.xml
# Shipping event dispatched: DPD_order_080294f0-d3ac-4dec-a8f1-0ba656c564de_PROD4015_dispatched.xml
# Shipping event picked up: DPD_order_080294f0-d3ac-4dec-a8f1-0ba656c564de_PROD4015_pickedup.xml
# Shipping event picked up: DPD_order_080294f0-d3ac-4dec-a8f1-0ba656c564de_PROD4015_pickedup.xml
# Shipping event dispatched: DPD_order_50da4f2d-725e-4905-87fa-8b60828bf61a_PROD4015_dispatched.xml
# Shipping event dispatched: DPD_order_50da4f2d-725e-4905-87fa-8b60828bf61a_PROD4015_dispatched.xml
# Shipping event picked up: DPD_order_50da4f2d-725e-4905-87fa-8b60828bf61a_PROD4015_pickedup.xml
# Shipping event picked up: DPD_order_50da4f2d-725e-4905-87fa-8b60828bf61a_PROD4015_pickedup.xml
# Shipping event dispatched: FedEx_order_72192698-18ef-48e0-b2da-03f317d5eae3_PROD4006_dispatched.xml
# Shipping event dispatched: FedEx_order_72192698-18ef-48e0-b2da-03f317d5eae3_PROD4006_dispatched.xml
# Shipping event picked up: FedEx_order_72192698-18ef-48e0-b2da-03f317d5eae3_PROD4006_pickedup.xml
# Shipping event picked up: FedEx_order_72192698-18ef-48e0-b2da-03f317d5eae3_PROD4006_pickedup.xml
# Shipping event dispatched: UPS_order_43b42064-6ee2-411b-ad15-5cc013d8a506_PROD4010_dispatched.xml
# Shipping event dispatched: UPS_order_43b42064-6ee2-411b-ad15-5cc013d8a506_PROD4010_dispatched.xml
# Shipping event picked up: UPS_order_43b42064-6ee2-411b-ad15-5cc013d8a506_PROD4010_pickedup.xml
# Shipping event picked up: UPS_order_43b42064-6ee2-411b-ad15-5cc013d8a506_PROD4010_pickedup.xml
# Shipping event routing: UPS_order_43b42064-6ee2-411b-ad15-5cc013d8a506_PROD4010_routing.xml
# Shipping event routing: UPS_order_43b42064-6ee2-411b-ad15-5cc013d8a506_PROD4010_routing.xml
# Shipping event dispatched: DPD_order_c521a823-eaaa-4e2d-a5d3-8662b9b5ff46_PROD4000_dispatched.xml
# Shipping event dispatched: DPD_order_c521a823-eaaa-4e2d-a5d3-8662b9b5ff46_PROD4000_dispatched.xml
# Shipping event dispatched: FedEx_order_24d362a6-6f31-4f7c-b217-b371221d0ef1_PROD4011_dispatched.xml
# Shipping event dispatched: FedEx_order_24d362a6-6f31-4f7c-b217-b371221d0ef1_PROD4011_dispatched.xml
# Shipping event picked up: FedEx_order_24d362a6-6f31-4f7c-b217-b371221d0ef1_PROD4011_pickedup.xml
# Shipping event picked up: FedEx_order_24d362a6-6f31-4f7c-b217-b371221d0ef1_PROD4011_pickedup.xml
# Shipping event dispatched: UPS_order_19d0ed88-6b1b-4fbc-95b8-de25e200d935_PROD4002_dispatched.xml
# Shipping event dispatched: UPS_order_19d0ed88-6b1b-4fbc-95b8-de25e200d935_PROD4002_dispatched.xml
# Shipping event dispatched: FedEx_order_8c429276-0c2d-4554-9445-f08f92e04e01_PROD4015_dispatched.xml
# Shipping event dispatched: FedEx_order_8c429276-0c2d-4554-9445-f08f92e04e01_PROD4015_dispatched.xml
# Shipping event picked up: FedEx_order_8c429276-0c2d-4554-9445-f08f92e04e01_PROD4015_pickedup.xml
# Shipping event picked up: FedEx_order_8c429276-0c2d-4554-9445-f08f92e04e01_PROD4015_pickedup.xml
# Shipping event dispatched: FedEx_order_6790ec2f-9259-41a4-9dbe-5bfa67e140e3_PROD4017_dispatched.xml
# Shipping event dispatched: FedEx_order_6790ec2f-9259-41a4-9dbe-5bfa67e140e3_PROD4017_dispatched.xml
# Shipping event dispatched: UPS_order_313edbd7-1e25-4693-b33f-c7a7084d6264_PROD4004_dispatched.xml
# Shipping event dispatched: UPS_order_313edbd7-1e25-4693-b33f-c7a7084d6264_PROD4004_dispatched.xml
# Shipping event picked up: UPS_order_313edbd7-1e25-4693-b33f-c7a7084d6264_PROD4004_pickedup.xml
# Shipping event picked up: UPS_order_313edbd7-1e25-4693-b33f-c7a7084d6264_PROD4004_pickedup.xml
# Shipping event routing: UPS_order_313edbd7-1e25-4693-b33f-c7a7084d6264_PROD4004_routing.xml
# Shipping event routing: UPS_order_313edbd7-1e25-4693-b33f-c7a7084d6264_PROD4004_routing.xml
# Shipping event dispatched: FedEx_order_b3c33833-15aa-4c43-9aa7-b0ca361201bc_PROD4013_dispatched.xml
# Shipping event dispatched: FedEx_order_b3c33833-15aa-4c43-9aa7-b0ca361201bc_PROD4013_dispatched.xml
# Shipping event dispatched: UPS_order_107642e1-8b25-4314-9cb3-403f750e0dfe_PROD4016_dispatched.xml
# Shipping event dispatched: UPS_order_107642e1-8b25-4314-9cb3-403f750e0dfe_PROD4016_dispatched.xml
# Shipping event picked up: UPS_order_107642e1-8b25-4314-9cb3-403f750e0dfe_PROD4016_pickedup.xml
# Shipping event picked up: UPS_order_107642e1-8b25-4314-9cb3-403f750e0dfe_PROD4016_pickedup.xml
# Shipping event dispatched: DPD_order_3dee4280-f9f2-4aaa-ae88-a2b7d4283d2e_PROD4005_dispatched.xml
# Shipping event dispatched: DPD_order_3dee4280-f9f2-4aaa-ae88-a2b7d4283d2e_PROD4005_dispatched.xml
# Shipping event dispatched: UPS_order_1f028d08-c810-4bcc-9771-6f745d6acf15_PROD4007_dispatched.xml
# Shipping event dispatched: UPS_order_1f028d08-c810-4bcc-9771-6f745d6acf15_PROD4007_dispatched.xml
# Shipping event picked up: UPS_order_1f028d08-c810-4bcc-9771-6f745d6acf15_PROD4007_pickedup.xml
# Shipping event picked up: UPS_order_1f028d08-c810-4bcc-9771-6f745d6acf15_PROD4007_pickedup.xml
# Shipping event dispatched: DPD_order_497262c0-78d3-4d76-bd06-402750ffb341_PROD4001_dispatched.xml
# Shipping event dispatched: DPD_order_497262c0-78d3-4d76-bd06-402750ffb341_PROD4001_dispatched.xml
# Shipping event picked up: DPD_order_497262c0-78d3-4d76-bd06-402750ffb341_PROD4001_pickedup.xml
# Shipping event picked up: DPD_order_497262c0-78d3-4d76-bd06-402750ffb341_PROD4001_pickedup.xml
# Shipping event dispatched: UPS_order_b26e411a-0312-44b5-bea7-4653e100b284_PROD4006_dispatched.xml
# Shipping event dispatched: UPS_order_b26e411a-0312-44b5-bea7-4653e100b284_PROD4006_dispatched.xml
# Shipping event picked up: UPS_order_b26e411a-0312-44b5-bea7-4653e100b284_PROD4006_pickedup.xml
# Shipping event picked up: UPS_order_b26e411a-0312-44b5-bea7-4653e100b284_PROD4006_pickedup.xml
# Shipping event dispatched: UPS_order_3415b755-f571-4a44-b87d-9494c0bcdfc2_PROD4004_dispatched.xml
# Shipping event dispatched: UPS_order_3415b755-f571-4a44-b87d-9494c0bcdfc2_PROD4004_dispatched.xml
# Shipping event picked up: UPS_order_3415b755-f571-4a44-b87d-9494c0bcdfc2_PROD4004_pickedup.xml
# Shipping event picked up: UPS_order_3415b755-f571-4a44-b87d-9494c0bcdfc2_PROD4004_pickedup.xml
# Shipping event routing: UPS_order_3415b755-f571-4a44-b87d-9494c0bcdfc2_PROD4004_routing.xml
# Shipping event routing: UPS_order_3415b755-f571-4a44-b87d-9494c0bcdfc2_PROD4004_routing.xml
# Shipping event dispatched: FedEx_order_2e214cf9-e41f-46af-ae61-ca8e475acee0_PROD4016_dispatched.xml
# Shipping event dispatched: FedEx_order_2e214cf9-e41f-46af-ae61-ca8e475acee0_PROD4016_dispatched.xml
# Shipping event picked up: FedEx_order_2e214cf9-e41f-46af-ae61-ca8e475acee0_PROD4016_pickedup.xml
# Shipping event picked up: FedEx_order_2e214cf9-e41f-46af-ae61-ca8e475acee0_PROD4016_pickedup.xml
# Shipping event routing: FedEx_order_2e214cf9-e41f-46af-ae61-ca8e475acee0_PROD4016_routing.xml
# Shipping event routing: FedEx_order_2e214cf9-e41f-46af-ae61-ca8e475acee0_PROD4016_routing.xml
# Shipping event dispatched: UPS_order_dc85be6d-ed3b-44c9-b550-377467965c65_PROD4002_dispatched.xml
# Shipping event dispatched: UPS_order_dc85be6d-ed3b-44c9-b550-377467965c65_PROD4002_dispatched.xml
# Shipping event dispatched: FedEx_order_76f392e4-95de-4359-8d36-888c3c18f1c3_PROD4013_dispatched.xml
# Shipping event dispatched: FedEx_order_76f392e4-95de-4359-8d36-888c3c18f1c3_PROD4013_dispatched.xml
# Shipping event dispatched: DPD_order_4a7e0971-35ec-430a-9179-153ae70ee785_PROD4018_dispatched.xml
# Shipping event dispatched: DPD_order_4a7e0971-35ec-430a-9179-153ae70ee785_PROD4018_dispatched.xml
# Shipping event picked up: DPD_order_4a7e0971-35ec-430a-9179-153ae70ee785_PROD4018_pickedup.xml
# Shipping event picked up: DPD_order_4a7e0971-35ec-430a-9179-153ae70ee785_PROD4018_pickedup.xml
# Shipping event routing: DPD_order_4a7e0971-35ec-430a-9179-153ae70ee785_PROD4018_routing.xml
# Shipping event routing: DPD_order_4a7e0971-35ec-430a-9179-153ae70ee785_PROD4018_routing.xml
# Shipping event dispatched: FedEx_order_97502f0f-1296-487e-96ef-b7a6052b1df4_PROD4015_dispatched.xml
# Shipping event dispatched: FedEx_order_97502f0f-1296-487e-96ef-b7a6052b1df4_PROD4015_dispatched.xml
# Shipping event picked up: FedEx_order_97502f0f-1296-487e-96ef-b7a6052b1df4_PROD4015_pickedup.xml
# Shipping event picked up: FedEx_order_97502f0f-1296-487e-96ef-b7a6052b1df4_PROD4015_pickedup.xml
# Shipping event dispatched: FedEx_order_7049441d-932f-45e0-a52a-d474ff734d6a_PROD4015_dispatched.xml
# Shipping event dispatched: FedEx_order_7049441d-932f-45e0-a52a-d474ff734d6a_PROD4015_dispatched.xml
# Shipping event picked up: FedEx_order_7049441d-932f-45e0-a52a-d474ff734d6a_PROD4015_pickedup.xml
# Shipping event picked up: FedEx_order_7049441d-932f-45e0-a52a-d474ff734d6a_PROD4015_pickedup.xml
# Shipping event dispatched: DPD_order_3d088df8-6f22-4718-b456-b4e2fec0fc30_PROD4011_dispatched.xml
# Shipping event dispatched: DPD_order_3d088df8-6f22-4718-b456-b4e2fec0fc30_PROD4011_dispatched.xml
# Shipping event picked up: DPD_order_3d088df8-6f22-4718-b456-b4e2fec0fc30_PROD4011_pickedup.xml
# Shipping event picked up: DPD_order_3d088df8-6f22-4718-b456-b4e2fec0fc30_PROD4011_pickedup.xml
# Shipping event routing: DPD_order_3d088df8-6f22-4718-b456-b4e2fec0fc30_PROD4011_routing.xml
# Shipping event routing: DPD_order_3d088df8-6f22-4718-b456-b4e2fec0fc30_PROD4011_routing.xml
# Shipping event dispatched: FedEx_order_884f91f9-2ba8-464c-95bf-19c07972076e_PROD4014_dispatched.xml
# Shipping event dispatched: FedEx_order_884f91f9-2ba8-464c-95bf-19c07972076e_PROD4014_dispatched.xml
# Shipping event picked up: FedEx_order_884f91f9-2ba8-464c-95bf-19c07972076e_PROD4014_pickedup.xml
# Shipping event picked up: FedEx_order_884f91f9-2ba8-464c-95bf-19c07972076e_PROD4014_pickedup.xml
# Shipping event dispatched: DPD_order_4c60dd8c-5c5c-4f29-b8ab-92dd8699e6a8_PROD4001_dispatched.xml
# Shipping event dispatched: DPD_order_4c60dd8c-5c5c-4f29-b8ab-92dd8699e6a8_PROD4001_dispatched.xml
# Shipping event dispatched: FedEx_order_d2b26d27-c223-4e8e-9c9b-b8a3056ca922_PROD4008_dispatched.xml
# Shipping event dispatched: FedEx_order_d2b26d27-c223-4e8e-9c9b-b8a3056ca922_PROD4008_dispatched.xml
# Shipping event dispatched: UPS_order_af6d255c-b50b-4a44-8551-a2d2ec0bf15a_PROD4018_dispatched.xml
# Shipping event dispatched: UPS_order_af6d255c-b50b-4a44-8551-a2d2ec0bf15a_PROD4018_dispatched.xml
# Shipping event dispatched: UPS_order_69ca6b75-6058-4c4c-9891-068f7c07c18f_PROD4017_dispatched.xml
# Shipping event dispatched: UPS_order_69ca6b75-6058-4c4c-9891-068f7c07c18f_PROD4017_dispatched.xml
# Shipping event picked up: UPS_order_69ca6b75-6058-4c4c-9891-068f7c07c18f_PROD4017_pickedup.xml
# Shipping event picked up: UPS_order_69ca6b75-6058-4c4c-9891-068f7c07c18f_PROD4017_pickedup.xml
# Shipping event routing: UPS_order_69ca6b75-6058-4c4c-9891-068f7c07c18f_PROD4017_routing.xml
# Shipping event routing: UPS_order_69ca6b75-6058-4c4c-9891-068f7c07c18f_PROD4017_routing.xml
# Shipping event dispatched: DPD_order_9d93f337-2177-4cd3-af1a-359783f0e174_PROD4010_dispatched.xml
# Shipping event dispatched: DPD_order_9d93f337-2177-4cd3-af1a-359783f0e174_PROD4010_dispatched.xml
# Shipping event picked up: DPD_order_9d93f337-2177-4cd3-af1a-359783f0e174_PROD4010_pickedup.xml
# Shipping event picked up: DPD_order_9d93f337-2177-4cd3-af1a-359783f0e174_PROD4010_pickedup.xml
# Shipping event routing: DPD_order_9d93f337-2177-4cd3-af1a-359783f0e174_PROD4010_routing.xml
# Shipping event routing: DPD_order_9d93f337-2177-4cd3-af1a-359783f0e174_PROD4010_routing.xml
# Shipping event dispatched: DPD_order_cf341454-bb48-4b18-9714-d473386cad68_PROD4002_dispatched.xml
# Shipping event dispatched: DPD_order_cf341454-bb48-4b18-9714-d473386cad68_PROD4002_dispatched.xml
# Shipping event picked up: DPD_order_cf341454-bb48-4b18-9714-d473386cad68_PROD4002_pickedup.xml
# Shipping event picked up: DPD_order_cf341454-bb48-4b18-9714-d473386cad68_PROD4002_pickedup.xml
# Shipping event routing: DPD_order_cf341454-bb48-4b18-9714-d473386cad68_PROD4002_routing.xml
# Shipping event routing: DPD_order_cf341454-bb48-4b18-9714-d473386cad68_PROD4002_routing.xml
# Shipping event dispatched: DPD_order_0cf8017b-fcb7-471f-bfc2-e1183ddb12f0_PROD4000_dispatched.xml
# Shipping event dispatched: DPD_order_0cf8017b-fcb7-471f-bfc2-e1183ddb12f0_PROD4000_dispatched.xml
# Shipping event dispatched: UPS_order_15ad6601-7160-4a3a-b03d-059afc06fdce_PROD4000_dispatched.xml
# Shipping event dispatched: UPS_order_15ad6601-7160-4a3a-b03d-059afc06fdce_PROD4000_dispatched.xml
# Shipping event dispatched: FedEx_order_5fb49f67-be59-4d24-87e0-c1abbf191a62_PROD4010_dispatched.xml
# Shipping event dispatched: FedEx_order_5fb49f67-be59-4d24-87e0-c1abbf191a62_PROD4010_dispatched.xml
# Shipping event picked up: FedEx_order_5fb49f67-be59-4d24-87e0-c1abbf191a62_PROD4010_pickedup.xml
# Shipping event picked up: FedEx_order_5fb49f67-be59-4d24-87e0-c1abbf191a62_PROD4010_pickedup.xml
# Shipping event routing: FedEx_order_5fb49f67-be59-4d24-87e0-c1abbf191a62_PROD4010_routing.xml
# Shipping event routing: FedEx_order_5fb49f67-be59-4d24-87e0-c1abbf191a62_PROD4010_routing.xml
# Shipping event dispatched: UPS_order_fee8e06b-d0d3-4710-afdb-13ae3094335f_PROD4008_dispatched.xml
# Shipping event dispatched: UPS_order_fee8e06b-d0d3-4710-afdb-13ae3094335f_PROD4008_dispatched.xml
# Shipping event picked up: UPS_order_fee8e06b-d0d3-4710-afdb-13ae3094335f_PROD4008_pickedup.xml
# Shipping event picked up: UPS_order_fee8e06b-d0d3-4710-afdb-13ae3094335f_PROD4008_pickedup.xml
# Shipping event routing: UPS_order_fee8e06b-d0d3-4710-afdb-13ae3094335f_PROD4008_routing.xml
# Shipping event routing: UPS_order_fee8e06b-d0d3-4710-afdb-13ae3094335f_PROD4008_routing.xml
# Shipping event dispatched: FedEx_order_e3084d51-6c06-4f69-87e9-ba94e55f49e4_PROD4003_dispatched.xml
# Shipping event dispatched: FedEx_order_e3084d51-6c06-4f69-87e9-ba94e55f49e4_PROD4003_dispatched.xml
# Shipping event picked up: FedEx_order_e3084d51-6c06-4f69-87e9-ba94e55f49e4_PROD4003_pickedup.xml
# Shipping event picked up: FedEx_order_e3084d51-6c06-4f69-87e9-ba94e55f49e4_PROD4003_pickedup.xml
# Shipping event routing: FedEx_order_e3084d51-6c06-4f69-87e9-ba94e55f49e4_PROD4003_routing.xml
# Shipping event routing: FedEx_order_e3084d51-6c06-4f69-87e9-ba94e55f49e4_PROD4003_routing.xml
# Shipping event dispatched: UPS_order_c49b3159-581f-4018-9d4c-eb1ca4b396a6_PROD4014_dispatched.xml
# Shipping event dispatched: UPS_order_c49b3159-581f-4018-9d4c-eb1ca4b396a6_PROD4014_dispatched.xml
# Shipping event picked up: UPS_order_c49b3159-581f-4018-9d4c-eb1ca4b396a6_PROD4014_pickedup.xml
# Shipping event picked up: UPS_order_c49b3159-581f-4018-9d4c-eb1ca4b396a6_PROD4014_pickedup.xml
# Shipping event routing: UPS_order_c49b3159-581f-4018-9d4c-eb1ca4b396a6_PROD4014_routing.xml
# Shipping event routing: UPS_order_c49b3159-581f-4018-9d4c-eb1ca4b396a6_PROD4014_routing.xml
# Shipping event dispatched: UPS_order_a2c7cde6-3c8a-47d5-8bbe-c0960fbb13ec_PROD4018_dispatched.xml
# Shipping event dispatched: UPS_order_a2c7cde6-3c8a-47d5-8bbe-c0960fbb13ec_PROD4018_dispatched.xml
# Shipping event picked up: UPS_order_a2c7cde6-3c8a-47d5-8bbe-c0960fbb13ec_PROD4018_pickedup.xml
# Shipping event picked up: UPS_order_a2c7cde6-3c8a-47d5-8bbe-c0960fbb13ec_PROD4018_pickedup.xml
# Shipping event dispatched: DPD_order_f6c82827-d750-418e-b06b-ab0d2f573623_PROD4017_dispatched.xml
# Shipping event dispatched: DPD_order_f6c82827-d750-418e-b06b-ab0d2f573623_PROD4017_dispatched.xml
# Shipping event picked up: DPD_order_f6c82827-d750-418e-b06b-ab0d2f573623_PROD4017_pickedup.xml
# Shipping event picked up: DPD_order_f6c82827-d750-418e-b06b-ab0d2f573623_PROD4017_pickedup.xml
# Shipping event dispatched: UPS_order_89e8abc5-06e5-4a51-971d-f026fdab4ac8_PROD4017_dispatched.xml
# Shipping event dispatched: UPS_order_89e8abc5-06e5-4a51-971d-f026fdab4ac8_PROD4017_dispatched.xml
# Shipping event picked up: UPS_order_89e8abc5-06e5-4a51-971d-f026fdab4ac8_PROD4017_pickedup.xml
# Shipping event picked up: UPS_order_89e8abc5-06e5-4a51-971d-f026fdab4ac8_PROD4017_pickedup.xml
# Shipping event dispatched: FedEx_order_929761df-901a-468f-9086-37badbeec3b5_PROD4007_dispatched.xml
# Shipping event dispatched: FedEx_order_929761df-901a-468f-9086-37badbeec3b5_PROD4007_dispatched.xml
